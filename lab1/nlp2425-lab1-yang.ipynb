# %% [markdown]
# **Másteres Universitarios en Ciencia de Datos, Ingeniería Informática, e Innovación en Inteligencia Computacional y Sistemas Interactivos, UAM**
# ## **Procesamiento del Lenguaje Natural**
# # **Práctica de laboratorio 1: Tareas de procesamiento del lenguaje natural**
#
#
# ---

# %% [markdown]
# En la esta práctica, se explorarán tareas de análisis gramatical y sintáctico utilizando la librería CoreNLP (https://stanfordnlp.github.io/CoreNLP/) y su cliente en Python, Stanza (https://stanfordnlp.github.io/stanza/).
#
# CoreNLP es una toolkit desarrollada por la Universidad de Stanford para realizar diversas tareas de PLN. Ofrece funcionalidades como el etiquetado gramatical (PoS tagging), el análisis sintáctico (tanto de constituyentes como de dependencias), el análisis de sentimientos, y el reconocimiento de entidades nombradas, entre otras. CoreNLP se destaca por su alta precisión y capacidad de análisis profundo del texto en varios idiomas, lo que la convierte en una herramienta muy utilizada en aplicaciones de PLN avanzadas.
#
# Stanza es una biblioteca en Python que actúa como un cliente para acceder a los modelos de CoreNLP. Simplifica el proceso de integración con CoreNLP, proporcionando una interfaz amigable y optimizada para realizar las tareas de PLN. A través de Stanza, es posible utilizar modelos entrenados por CoreNLP en distintos lenguajes para las citadas tareas.
#
# En la práctica, se abordarán las siguientes tareas de PLN:
#
# - Análisis gramatical: Asignar una categoría gramatical (sustantivo, verbo, adjetivo, etc.) a cada palabra de un texto.
# - Análisis sintáctico de constituyentes: Identificar los grupos o constituyentes dentro de una oración (por ejemplo, frases nominales, verbales, adjetivales, etc.), que son componentes clave para comprender la estructura de la oración.
# - Análisis sintáctico de dependencias: Identificar las relaciones de dependencia entre las palabras de una oración, es decir, cómo las palabras se conectan entre sí a través de enlaces sintácticos.
# - Aplicación de minería de opinión a partir de resultados de las tareas anteriores. Especificamente, la extracción de opiniones sobre aspectos, tales como atributos y elementos de productos, servicios o eventos.
#
# Mediante el uso de categorías gramaticales y dependencias sintácticas (como las relaciones de “modificación” entre adjetivos y sustantivos), será posible identificar opiniones expresadas sobre ciertos aspectos en reseñas, por ejemplo, en la oración "El teléfono móvil tiene una excelente cámara" se descompondrá para identificar la opinión sobre la calidad de la cámara de un teléfono.

# %% [markdown]
# ### Etiquetado gramatical y análisis sintáctico con CoreNLP

# %% [markdown]
# ***Carga de modelo y pipeline de procesamiento***

# %%
# %pip install stanza

# Importamos Stanza, cliente de acceso a la librería CoreNLP
import stanza

# Si no se ha hecho previamente, descargamos el modelo de CoreNLP preentrenado en inglés
#stanza.download('en')  # Descomentar solo la primera vez
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cargamos el modelo y lo encapsulamos en un pipeline de procesadores de lenguaje natural:
# - tokenize, mwt: sentence and word tokenizers
# - pos: part-of-speech tagger
# - lemma: lemmatizer
# - constituency, depparse: constituency and dependency parsers
# - sentiment: sentiment analyzer
# - ner: name entity recognizer
nlp = stanza.Pipeline('en')
# Out:
# 2026-02-13 17:21:04 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2026-02-13 17:21:04 INFO: Downloaded file to /Users/gaelscomputer/stanza_resources/resources.json
# 2026-02-13 17:21:05 INFO: Loading these models for language: en (English):
# ...
# | Processor    | Package                   |
# --------------------------------------------
# | tokenize     | combined                  |
# | mwt          | combined                  |
# | pos          | combined_charlm           |
# | lemma        | combined_nocharlm         |
# | constituency | ptb3-revised_charlm       |
# | depparse     | combined_charlm           |
# | sentiment    | sstplus_charlm            |
# | ner          | ontonotes-ww-multi_charlm |
# ...
#
# 2026-02-13 17:21:05 INFO: Using device: cpu
# 2026-02-13 17:21:05 INFO: Loading: tokenize
# 2026-02-13 17:21:05 INFO: Loading: mwt
# ...

# %%
# Establecemos el texto a analizar: una reseña sobre un teléfono móvil
review = """
        The phone is okay, but it doesn't meet all my expectations. 
        Its camera is not as good as I expected; in low light, the photos come out blurry. 
        The price is too high for the features it offers. What disappoints me the most is the battery, which doesn't last long. 
        Its design, on the other hand, is quite nice and comfortable to use."
        """

# %% [markdown]
# ***Etiquetado gramatical - Part-of-Speech (PoS) tagging***

# %%
# Preprocesamos la review (si se considera necesario)
#review = review.lower()

# Procesar la review con Stanza (cliente CoreNLP)
doc = nlp(review)

for sentence in doc.sentences:
    print(f"Sentence: '{sentence.text}'")
# Out:
# Sentence: 'The phone is okay, but it doesn't meet all my expectations.'
# Sentence: 'Its camera is not as good as I expected; in low light, the photos come out blurry.'
# Sentence: 'The price is too high for the features it offers.'
# Sentence: 'What disappoints me the most is the battery, which doesn't last long.'
# Sentence: 'Its design, on the other hand, is quite nice and comfortable to use."'

# %%
# Imprimimos por pantalla tablas con los etiquetados gramaticales de las oraciones de la reseña
for sentence in doc.sentences:
    print("\n*** PoS tags ***")
    print(f"Sentence: '{sentence.text}'")
    
    print(f"{'ID':<5} {'Word':<15} {'PoS Tag':<15} {'XPOS Tag':<15}")
    print("-" * 50)
    
    for word in sentence.words:
        print(f"{word.id:<5} {word.text:<15} {word.upos:<15} {word.xpos:<15}")
# Out:
# *** PoS tags ***
# Sentence: 'The phone is okay, but it doesn't meet all my expectations.'
# ID    Word            PoS Tag         XPOS Tag
# --------------------------------------------------
# 1     The             DET             DT
# 2     phone           NOUN            NN
# 3     is              AUX             VBZ
# 4     okay            ADJ             JJ
# 5     ,               PUNCT           ,
# 6     but             CCONJ           CC
# 7     it              PRON            PRP
# 8     does            AUX             VBZ
# 9     n't             PART            RB
# 10    meet            VERB            VB
# 11    all             DET             PDT
# 12    my              PRON            PRP$
# 13    expectations    NOUN            NNS
# 14    .               PUNCT           .
#
# *** PoS tags ***
# Sentence: 'Its camera is not as good as I expected; in low light, the photos come out blurry.'
# ID    Word            PoS Tag         XPOS Tag
# ...

# %% [markdown]
# ***PREGUNTA 1***. ¿Cuál es el significado y posibles valores de word.upos y word.xpos?

# %% [markdown]
# [RESPUESTA AQUÍ]

# %% [markdown]
# word.upos word.upos is a universal part-of-speech tag.
# It provides a universal and coarse-grained part-of-speech category.
#
#     NOUN(noun),NUM(numeral),ADJ(adjective),ADP(adposition),ADV(adverb),
#     AUX(auxiliary verb),CCONJ(coordinating sonjunction),DET(determiner),
#     INTJ(interhection),PART(particle),PRON(pronoun),PROPN(proper noun),
#     PUNCT(punctuation),SCONJ(subordinating conjunction),SYM(symbol),VERB(verb),X(other),etc.
#
#
# word.xpos provides a language-specific and fine-grained POS tag, encoding richer grammatical information.
# word.xpos represents fine-grained part-of-speech tagging,which extends the universal POS tag (word.upos) by encoding more detailed grammatical information, such as:
#
#     1. Nouns
#         NN — Common noun, singular
#         NNS — Common noun, plural
#         NNP — Proper noun, singular
#         NNPS — Proper noun, plural
#     2. Verbs
#         VB — Base form verb
#         VBD — Past tense verb
#         VBG — Gerund / present participle
#         VBN — Past participle
#         VBP — Non-third-person singular present
#         VBZ — Third-person singular present
#     3. Adjectives
#         JJ — Adjective
#         JJR — Comparative adjective
#         JJS — Superlative adjective
#     4. Adverbs
#         RB — Adverb
#         RBR — Comparative adverb
#         RBS — Superlative adverb
#     5. Determiners
#         DT — Determiner
#         PDT — Predeterminer
#         WDT — Wh-determiner
#     6. Pronouns
#         PRP — Personal pronoun
#         PRP$ — Possessive pronoun
#         WP — Wh-pronoun
#         WP$ — Possessive wh-pronoun
#     7. Conjunctions / Prepositions
#         CC — Coordinating conjunction
#         IN — Preposition or subordinating conjunction
#     8. Other categories
#         CD — Cardinal number
#         TO — Infinitival “to”
#         MD — Modal verb
#         UH — Interjection
#         POS — Possessive ending
#         SYM — Symbol
#         PUNCT — Punctuation

# %% [markdown]
# ***Análisis de constituyentes - Constituency parsing***

# %%
# Función recursiva para imprimir por pantalla un árbol de constituyentes
def print_constituency_tree(constituency, level):
    node_text = constituency.label
    children = constituency.children
    
    indent = "  " * level
    print(f"{indent}{node_text}")
    
    for child in children:
        if isinstance(child, str):
            print(f"{indent}  {child}")
        else:
            print_constituency_tree(child, level + 1)

# Imprimimos por pantalla el análisis de constituyentes de las oraciones de la reseña
for sentence in doc.sentences:
    print("\n*** Constituency parse ***")
    print(f"Sentence: '{sentence.text}'")

    constituency = sentence.constituency
    print(f"Parse (bracket notation):\n{constituency}")
    
    # Ahora, imprimimos la estructura en formato de taxonomía o directorio
    print("Parse (tree format):")
    print_constituency_tree(constituency, 0)
# Out:
# *** Constituency parse ***
# Sentence: 'The phone is okay, but it doesn't meet all my expectations.'
# Parse (bracket notation):
# (ROOT (S (S (NP (DT The) (NN phone)) (VP (VBZ is) (ADJP (JJ okay)))) (, ,) (CC but) (S (NP (PRP it)) (VP (VBZ does) (RB n't) (VP (VB meet) (NP (PDT all) (PRP$ my) (NNS expectations))))) (. .)))
# Parse (tree format):
# ROOT
#   S
#     S
#       NP
#         DT
#           The
#         NN
#           phone
#       VP
#         VBZ
#           is
#         ADJP
#           JJ
#             okay
#     ,
#       ,
#     CC
#       but
#     S
#       NP
#         PRP
#           it
#       VP
#         VBZ
#           does
#         RB
#           n't
#         VP
#           VB
#             meet
#           NP
#             PDT
#               all
#             PRP$
#               my
#             NNS
#               expectations
#     .
#       .
#
# *** Constituency parse ***
# ...

# %% [markdown]
# ***PREGUNTA 2***. ¿Qué tipos de información aportan los valores de los nodos de los árboles sintácticos anteriores?

# %% [markdown]
# [RESPUESTA AQUÍ]

# %% [markdown]
# 1. Objeto de nodo del árbol `constituency`, cada nodo es un objeto.
#    1. `constituency.label`: representa la etiqueta del nodo. Proporciona la categoría correspondiente de la frase o estructura de la oración. Por ejemplo: `S` representa *sentence* (oración), `VP` representa *verb phrase* (frase verbal).
#    2. `constituency.children`: representa los nodos hijos. Proporciona la información de las palabras como cadenas de texto, por ejemplo: `The`, `phone`, `is`, `okay`. También puede representar nodos no terminales, es decir, otro objeto `constituency` que indica una subfrase o una oración subordinada.
#
# 2. Información implícita (en el objeto subyacente), proporciona la categoría gramatical (POS) y el índice de posición. Por ejemplo: `PRON`, `VERB` y la posición de la palabra dentro de la oración.

# %% [markdown]
# ***Análisis de dependencias - Dependency parsing***

# %%
# Imprimimos por pantalla tablas con las depedencias en cada oración de la reseña
for sentence in doc.sentences:
    print("\n*** Dependency parse ***")
    print(f"Sentence: '{sentence.text}'")

    print(f"{'ID':<5} {'Word':<15} {'Head ID':<10} {'Head Word':<15} {'Deprel':<15}")
    print("-" * 60)
    
    for word in sentence.words:
        head_word = sentence.words[word.head - 1] if word.head > 0 else None
        print(f"{word.id:<5} {word.text:<15} {word.head:<10} {head_word.text if head_word else 'None':<15} {word.deprel:<15}")
# Out:
# *** Dependency parse ***
# Sentence: 'The phone is okay, but it doesn't meet all my expectations.'
# ID    Word            Head ID    Head Word       Deprel
# ------------------------------------------------------------
# 1     The             2          phone           det
# 2     phone           4          okay            nsubj
# 3     is              4          okay            cop
# 4     okay            0          None            root
# 5     ,               10         meet            punct
# 6     but             10         meet            cc
# 7     it              10         meet            nsubj
# 8     does            10         meet            aux
# 9     n't             10         meet            advmod
# 10    meet            4          okay            conj
# 11    all             13         expectations    det:predet
# 12    my              13         expectations    nmod:poss
# 13    expectations    10         meet            obj
# ...

# %%
# Imprimimos por pantalla tablas con las depedencias en cada oración de la reseña, acompañadas con los PoS del word (dependent) y head de cada dependencia.
for sentence in doc.sentences:
    print("\n*** Dependency parse with POS tags ***")
    print(f"Sentence: '{sentence.text}'")
    
    print(f"{'ID':<5} {'Word':<15} {'Word POS':<10} {'Head ID':<10} {'Head Word':<15} {'Head POS':<10} {'Deprel':<15}")
    print("-" * 80)
    
    for word in sentence.words:
        head_word = sentence.words[word.head - 1] if word.head > 0 else None
        head_pos = head_word.upos if head_word else 'None'
        print(f"{word.id:<5} {word.text:<15} {word.upos:<10} {word.head:<10} {head_word.text if head_word else 'None':<15} {head_pos:<10} {word.deprel:<15}")
# Out:
# *** Dependency parse with POS tags ***
# Sentence: 'The phone is okay, but it doesn't meet all my expectations.'
# ID    Word            Word POS   Head ID    Head Word       Head POS   Deprel
# --------------------------------------------------------------------------------
# 1     The             DET        2          phone           NOUN       det
# 2     phone           NOUN       4          okay            ADJ        nsubj
# 3     is              AUX        4          okay            ADJ        cop
# 4     okay            ADJ        0          None            None       root
# 5     ,               PUNCT      10         meet            VERB       punct
# 6     but             CCONJ      10         meet            VERB       cc
# 7     it              PRON       10         meet            VERB       nsubj
# 8     does            AUX        10         meet            VERB       aux
# 9     n't             PART       10         meet            VERB       advmod
# ...

# %% [markdown]
# ***PREGUNTA 3***. ¿Qué significan las relaciones 'nsubj', 'amod', 'advmod' y 'conj'? Al definir cada relación, incluye ejemplos (word, deprel, head) de las tablas anteriores en las que la relación aparece.

# %% [markdown]
# [RESPUESTA AQUÍ]

# %% [markdown]
# 1. ´nsubj´ indica el sujeto de la oración y su función es conectar el verbo con su sujeto.
#
#     Ejemplo: The phone is okay, but it doesn't meet all my expectations.
#
#     ➡️Los sujetos son phone e it, donde phone es el sujeto de is e it es el sujeto de meet.
#
# 2. ´amod´ indica un modificador adjetival, cuya función es conectar un sustantivo con el adjetivo que lo modifica.
#
#     Ejemplo: The price is too high for the features it offers. What disappoints me the most is the battery, which doesn't last long.
#
#     ➡️high modifica a price, indicando que el precio es demasiado alto.
#
# 3. ´dvmod´ indica un modificador adverbial, que modifica un verbo, adjetivo o adverbio.
#
#     Ejemplo: Its camera is not as good as I expected; in low light, the photos come out blurry.
#
#     ➡️not modifica al verbo is, indicando negación.
#
# 4. ´conj´ indica una relación de coordinación, cuya función es conectar dos elementos del mismo tipo.
#
#     Ejemplo: The phone is okay, but it doesn't meet all my expectations.
#
#     ➡️is y meet están conectados mediante conj, y la conjunción but conecta las dos partes de la oración.

# %% [markdown]
# ### Extracción de opiniones sobre aspectos (de un producto) en una reseña.

# %%
def extract_aspect_opinion_pairs(review):
    doc = nlp(review)
    pairs = []

    for sentence in doc.sentences:
        for word in sentence.words:
            head_word = sentence.words[word.head - 1] if word.head > 0 else None
            head_pos = head_word.upos if head_word else 'None'
            
            if word.upos in {"NOUN", "PROPN"}:
                if head_word and head_word.upos == "ADJ":
                    pair = (word.text, head_word.text)
                    if pair not in pairs:
                        pairs.append(pair)
                        print(f"1. {pair}")

            if word.upos == "ADJ":
                if head_word and head_word.upos in {"NOUN", "PROPN"}:
                    pair = (word.text, head_word.text)
                    if pair not in pairs:
                        pairs.append(pair)
                        print(f"2. {pair}")

    return pairs

print(review)
pairs = extract_aspect_opinion_pairs(review)
#print(pairs)
# Out:
#         The phone is okay, but it doesn't meet all my expectations.
#         Its camera is not as good as I expected; in low light, the photos come out blurry.
#         The price is too high for the features it offers. What disappoints me the most is the battery, which doesn't last long.
#         Its design, on the other hand, is quite nice and comfortable to use."
#
# 1. ('phone', 'okay')
# 1. ('camera', 'good')
# 2. ('low', 'light')
# 1. ('price', 'high')
# 1. ('features', 'high')
# 2. ('most', 'battery')
# 1. ('design', 'nice')
# 2. ('other', 'hand')
# 1. ('hand', 'nice')

# %% [markdown]
# ***PREGUNTA 4***. ¿Cuál es el propósito de la función extract_aspect_opinion_pairs? ¿Qué errores observas en los resultados? ¿Cómo se podrían abordar dichos errores?

# %% [markdown]
# 1. El propósito de la función extract_aspect_opinion_pairs es extraer automáticamente los pares aspecto-opinión a partir de un texto de reseña.
#
#     -Aspecto (aspect): generalmente un sustantivo o nombre propio, por ejemplo: phone, camera.
#
#     -Opinión (opinion): generalmente un adjetivo, por ejemplo: good, high.
#
# 2. Errores observados:
#
#     (1) Coincidencia incorrecta
#         - Por ejemplo, most no modifica battery; en la oración, the most actúa como adverbio de grado que modifica la intensidad del verbo disappoints.
#         - La función solo considera la relación entre sustantivos y adjetivos, sin tener en cuenta que algunos adjetivos pueden modificar cláusulas o sustantivos que no son aspectos; tampoco considera que algunas expresiones requieren el artículo definido para funcionar como adverbio.
#
#     (2) No solo los adjetivos pueden modificar sustantivos, los adverbios también pueden hacerlo.
#
#     (3) Inconsistencia en el orden
#         - Los resultados pueden ser (adjetivo, sustantivo) o (sustantivo, adjetivo).
#         - Ejemplo: ('phone', 'okay') y ('low', 'light').
#
#     (4) No se considera la afirmación o negación del adjetivo
#         - Ejemplo: Its camera is not as good as I expected.
#         - Resultado actual: ('camera', 'good').
#         - Pero en realidad expresa: Its camera is NOT good.
#
# 3. Cómo solucionar:
#
#     (1) Almacenar siempre en la forma (aspect, opinion), para evitar inconsistencias de orden.
#
#     (2) Considerar la negación y los adverbios que modifican el adjetivo o el verbo.
#
#     (3) Realizar un procesamiento y normalización final, para evitar coincidencias incorrectas.

# %% [markdown]
# ***PREGUNTA 5***. Extiende el código de la función extract_aspect_opinion_pairs para encontrar más resultados potencialmente válidos. Si es necesario, modifica/extiende el texto de la reseña analizada.

# %%
nlp = stanza.Pipeline('en', processors='tokenize,mwt,pos,lemma,depparse', tokenize_no_ssplit=False)

def extract_aspect_opinion_pairs(review):
    doc = nlp(review)
    pairs = []

    for sentence in doc.sentences:
        for word in sentence.words:
            # 跳过非主要词
            if word.upos not in {"NOUN", "PROPN", "ADJ", "ADV"}:
                continue

            # 获取头节点
            head_word = sentence.words[word.head - 1] if word.head > 0 else None

            # 1️⃣ 捕捉否定词
            negation = ""
            for child in sentence.words:
                if child.head == word.id and child.deprel == "advmod" and child.text.lower() in {"not", "never"}:
                    negation = child.text.lower() + " "

            # 2️⃣ 处理复合名词
            if word.upos in {"NOUN", "PROPN"}:
                compound = [word.text]
                for child in sentence.words:
                    if child.head == word.id and child.deprel == "compound":
                        compound.insert(0, child.text)
                aspect = " ".join(compound)

                # 名词依赖形容词/副词
                if head_word and head_word.upos in {"ADJ", "ADV"}:
                    # 排除修饰从句的程度副词，例如 the most
                    if head_word.text.lower() not in {"most"}:
                        pair = (aspect, negation + head_word.text)
                        if pair not in pairs:
                            pairs.append(pair)
                            print(f"Aspect->Opinion: {pair}")

            # 3️⃣ 形容词/副词依赖名词/专有名词
            if word.upos in {"ADJ", "ADV"}:
                if head_word and head_word.upos in {"NOUN", "PROPN"}:
                    # 排除修饰从句或动作的程度副词
                    if word.text.lower() not in {"most"}:
                        # 处理复合名词
                        compound = [head_word.text]
                        for child in sentence.words:
                            if child.head == head_word.id and child.deprel == "compound":
                                compound.insert(0, child.text)
                        aspect = " ".join(compound)
                        pair = (aspect, negation + word.text)
                        if pair not in pairs:
                            pairs.append(pair)
                            print(f"Aspect->Opinion: {pair}")

    return pairs


print("原评论:\n", review)
pairs = extract_aspect_opinion_pairs(review)
print("\n提取的 Aspect-Opinion 对：")
print(pairs)
# Out:
# 2026-02-13 17:27:23 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2026-02-13 17:27:23 INFO: Downloaded file to /Users/gaelscomputer/stanza_resources/resources.json
# 2026-02-13 17:27:24 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# ...
#
# 2026-02-13 17:27:24 INFO: Using device: cpu
# 2026-02-13 17:27:24 INFO: Loading: tokenize
# 2026-02-13 17:27:24 INFO: Loading: mwt
# 2026-02-13 17:27:24 INFO: Loading: pos
# 2026-02-13 17:27:25 INFO: Loading: lemma
# 2026-02-13 17:27:25 INFO: Loading: depparse
# 2026-02-13 17:27:25 INFO: Done loading processors!
# 原评论:
#
# ...

# %% [markdown]
# ***PREGUNTA 6***. ¿Faltarían más casos por abordar en la función extract_aspect_opinion_pairs? En caso afirmativo, descríbelos brevemente.

# %% [markdown]
# [RESPUESTA AQUÍ]

# %% [markdown]
# 1. Todavía no se captura la negación "not", lo que indica que la función no extrae completamente opiniones de varias palabras (multi-palabra).
#
# 2. La cláusula relacionada con "battery" no se extrajo, y hubo una coincidencia incorrecta: Aspect->Opinion: ('features', 'high').
#
# 3. En "nice and comfortable" solo se extrajo el primer adjetivo, por lo que es necesario manejar la relación de coordinación (conj).
#
# 4. Las combinaciones de verbo y sustantivo no se extrajeron.

# %% [markdown]
# ***PREGUNTA 7***. ¿Con lo anterior se podría determinar la polaridad (positiva, negativa) de las opiniones? ¿Cómo se haría? ¿Habría alguna complicación al respecto (en base a los resultados mostrados en la versión original de la función extract_aspect_opinion_pairs?

# %% [markdown]
# [RESPUESTA AQUÍ]

# %% [markdown]
# 1. Cada par aspecto-opinión puede proporcionar la orientación del sentimiento para un aspecto específico.
#
#     -Positivo: por ejemplo, ('phone', 'okay'), ('design', 'nice')
#
#     -Negativo: por ejemplo, ('camera', 'good') (si se considera la negación, debería ser 'not good'), ('price', 'high')
#
#     Por lo tanto, se puede estimar de manera aproximada el sentimiento general del comentario:
#
#     -La mayoría son positivos ➡️ el comentario es predominantemente positivo
#
#     -La mayoría son negativos ➡️ el comentario es predominantemente negativo
#
# 2. Se puede asignar un valor a cada opinión:
#
#     -Usando un diccionario de sentimientos o un modelo de sentimiento preentrenado, convertir la opinión en un valor numérico:
#
#         -not good ➡️ -1
#         -okay ➡️ +1
#
# 3. Dificultades existentes:
#
#     (1) La negación no fue capturada:
#
#         - Por ejemplo, ('camera', 'good') en realidad debería ser ('camera', 'not good')
#         - La función original no maneja opiniones de varias palabras, lo que puede causar errores en la determinación del sentimiento positivo o negativo
#
#     (2) Coincidencias incorrectas:
#
#         - ('features', 'high') no representa realmente una opinión negativa, pero fue extraído ➡️ posible error de juicio
#
#     (3) Adjetivos en conjunción no completamente extraídos:
#
#         - 'nice and comfortable' solo se extrajo 'nice', se omitió 'comfortable'
#         - La estadística de sentimientos queda incompleta
#
#     (4) Combinaciones de verbo + sustantivo no extraídas:
#
#         - 'it doesn't meet all my expectations' ➡️ ('expectations', 'not meet') no se extrajo
#         - Esto provoca que se pierdan opiniones negativas y el sentimiento general se vea sesgado hacia lo positivo
#
#     (5) Opiniones de varias palabras no procesadas correctamente:
#
#         - 'not as good', "doesn't last long", etc., no fueron completamente capturadas
